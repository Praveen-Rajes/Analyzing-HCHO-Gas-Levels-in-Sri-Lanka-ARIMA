# %%
# %run Data_Read.ipynb

# %%
Kandy = Kandy_df
Colombo = colombo_df
Deniyaya = Deniyaya_df
Nuwara_Eliya = Nuwara_Eliya_df
Bibile = Bibile_df
Kurunegala = Kurunegala_df
Jaffna = Jaffna_df

# %%
#caluclation of the monthly mean of the data for each city
Kandy_monthly_mean = Kandy.resample('M').mean()
Colombo_monthly_mean = Colombo.resample('M').mean()
Deniyaya_monthly_mean = Deniyaya.resample('M').mean()
Nuwara_Eliya_monthly_mean = Nuwara_Eliya.resample('M').mean()
Bibile_monthly_mean = Bibile.resample('M').mean()
Kurunegala_monthly_mean = Kurunegala.resample('M').mean()
Jaffna_monthly_mean = Jaffna.resample('M').mean()

# %%
import matplotlib.pyplot as plt

# Assuming you have your dataframes Kandy_monthly_mean, Colombo_monthly_mean, etc.

fig, axs = plt.subplots(4, 2, figsize=(15, 15))
fig.suptitle('Monthly mean of the data for each city')

# Plotting each city's monthly mean data and setting lockdown period for each subplot
Kandy_monthly_mean.plot(ax=axs[0, 0], title='Kandy')
axs[0, 0].axvspan('2020-05-01', '2022-04-01', color='red', alpha=0.5)

Colombo_monthly_mean.plot(ax=axs[0, 1], title='Colombo')
axs[0, 1].axvspan('2020-05-01', '2022-04-01', color='red', alpha=0.5)

Deniyaya_monthly_mean.plot(ax=axs[1, 0], title='Deniyaya')
axs[1, 0].axvspan('2020-05-01', '2022-04-01', color='red', alpha=0.5)

Nuwara_Eliya_monthly_mean.plot(ax=axs[1, 1], title='Nuwara Eliya')
axs[1, 1].axvspan('2020-05-01', '2022-04-01', color='red', alpha=0.5)

Bibile_monthly_mean.plot(ax=axs[2, 0], title='Bibile')
axs[2, 0].axvspan('2020-05-01', '2022-04-01', color='red', alpha=0.5)

Kurunegala_monthly_mean.plot(ax=axs[2, 1], title='Kurunegala')
axs[2, 1].axvspan('2020-05-01', '2022-04-01', color='red', alpha=0.5)

Jaffna_monthly_mean.plot(ax=axs[3, 0], title='Jaffna')
axs[3, 0].axvspan('2020-05-01', '2022-04-01', color='red', alpha=0.5)

# Hiding the last subplot since it's not used
axs[3, 1].axis('off')

plt.tight_layout()
plt.subplots_adjust(top=0.95)
plt.show()

# %%
# Plotting all city's monthly mean data and setting lockdown period for each bar chart in a single plot
fig, ax = plt.subplots(figsize=(15, 5))
fig.suptitle('Monthly mean of the data for each city')

Kandy_monthly_mean.plot(ax=ax, title='Monthly mean of the data for each city')
ax.axvspan('2020-05-01', '2022-04-01', color='red', alpha=0.5)

Colombo_monthly_mean.plot(ax=ax)
ax.axvspan('2020-05-01', '2022-04-01', color='red', alpha=0.5)

Deniyaya_monthly_mean.plot(ax=ax)
ax.axvspan('2020-05-01', '2022-04-01', color='red', alpha=0.5)

Nuwara_Eliya_monthly_mean.plot(ax=ax)
ax.axvspan('2020-05-01', '2022-04-01', color='red', alpha=0.5)

Bibile_monthly_mean.plot(ax=ax)
ax.axvspan('2020-05-01', '2022-04-01', color='red', alpha=0.5)

Kurunegala_monthly_mean.plot(ax=ax)
ax.axvspan('2020-05-01', '2022-04-01', color='red', alpha=0.5)

Jaffna_monthly_mean.plot(ax=ax)
ax.axvspan('2020-05-01', '2022-04-01', color='red', alpha=0.5)

plt.show()

# %%
import matplotlib.pyplot as plt

# Define the lockdown period
lockdown_start = '2020-05-01'
lockdown_end = '2022-04-01'

# Filter the data for the lockdown period
lockdown_data = Bibile_df.loc[lockdown_start:lockdown_end]



# Extract the HCHO values for each city
bibile_before = Bibile_before['HCHO Value']
bibile_on = Bibile_on['HCHO Value']
bibile_after = Bibile_after['HCHO Value']



# Create the bar chart
fig, ax = plt.subplots(figsize=(10, 6))

# Set the x-axis labels
x_labels = ['Bibile', 'Colombo', 'Deniyaya']
x = range(len(x_labels))

# Set the y-axis values
y_before = [bibile_before, colombo_before, deniyaya_before]
y_on = [bibile_on, colombo_on, deniyaya_on]
y_after = [bibile_after, colombo_after, deniyaya_after]

# Plot the bars
bar_width = 0.25
ax.bar(x, y_before, width=bar_width, label='Before Lockdown')
ax.bar([i + bar_width for i in x], y_on, width=bar_width, label='During Lockdown')
ax.bar([i + 2 * bar_width for i in x], y_after, width=bar_width, label='After Lockdown')

# Set the x-axis tick labels
ax.set_xticks([i + bar_width for i in x])
ax.set_xticklabels(x_labels)

# Set the y-axis label
ax.set_ylabel('HCHO Value')

# Set the chart title
ax.set_title('HCHO Values Before, During, and After Lockdown')

# Add a legend
ax.legend()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16236\2730891582.py in <module>
#      11
#      12 # Extract the HCHO values for each city
# ---> 13 bibile_before = Bibile_before['HCHO Value']
#      14 bibile_on = Bibile_on['HCHO Value']
#      15 bibile_after = Bibile_after['HCHO Value']
#
# NameError: name 'Bibile_before' is not defined

# %%
# diplay the HCHO values for each city in bar chart indication before , on , after lockdown for each city in one plot
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have your dataframes Kandy, Colombo, etc.

fig, ax = plt.subplots(figsize=(15, 5))
fig.suptitle('HCHO values for each city before, on, and after lockdown')

# Getting the mean HCHO values for each city before, on, and after lockdown
Kandy_before = Kandy['2020-03-01':'2020-04-30'].mean()
Kandy_on = Kandy['2020-05-01':'2022-04-01'].mean()
Kandy_after = Kandy['2022-05-01':].mean()

Colombo_before = Colombo['2020-03-01':'2020-04-30'].mean()
Colombo_on = Colombo['2020-05-01':'2022-04-01'].mean()
Colombo_after = Colombo['2022-05-01':].mean()

Deniyaya_before = Deniyaya['2020-03-01':'2020-04-30'].mean()
Deniyaya_on = Deniyaya['2020-05-01':'2022-04-01'].mean()
Deniyaya_after = Deniyaya['2022-05-01':].mean()

Nuwara_Eliya_before = Nuwara_Eliya['2020-03-01':'2020-04-30'].mean()
Nuwara_Eliya_on = Nuwara_Eliya['2020-05-01':'2022-04-01'].mean()
Nuwara_Eliya_after = Nuwara_Eliya['2022-05-01':].mean()

Bibile_before = Bibile['2020-03-01':'2020-04-30'].mean()
Bibile_on = Bibile['2020-05-01':'2022-04-01'].mean()
Bibile_after = Bibile['2022-05-01':].mean()

Kurunegala_before = Kurunegala['2020-03-01':'2020-04-30'].mean()
Kurunegala_on = Kurunegala['2020-05-01':'2022-04-01'].mean()
Kurunegala_after = Kurunegala['2022-05-01':].mean()

Jaffna_before = Jaffna['2020-03-01':'2020-04-30'].mean()
Jaffna_on = Jaffna['2020-05-01':'2022-04-01'].mean()
Jaffna_after = Jaffna['2022-05-01':].mean()

# Plotting the mean HCHO values for each city before, on, and after lockdown
barWidth = 0.25
r1 = np.arange(len([Kandy_before, Colombo_before, Deniyaya_before, Nuwara_Eliya_before, Bibile_before, Kurunegala_before, Jaffna_before]))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

ax.bar(r1, [Kandy_before, Colombo_before, Deniyaya_before, Nuwara_Eliya_before, Bibile_before, Kurunegala_before, Jaffna_before], color='b', width=barWidth, edgecolor='grey', label='Before lockdown')
ax.bar(r2, [Kandy_on, Colombo_on, Deniyaya_on, Nuwara_Eliya_on, Bibile_on, Kurunegala_on, Jaffna_on], color='r', width=barWidth, edgecolor='grey', label='On lockdown')
ax.bar(r3, [Kandy_after, Colombo_after, Deniyaya_after, Nuwara_Eliya_after, Bibile_after, Kurunegala_after, Jaffna_after], color='g', width=barWidth, edgecolor='grey', label='After lockdown')

ax.set_xlabel('City')
ax.set_ylabel('HCHO values')
ax.set_xticks([r + barWidth for r in range(len([Kandy_before, Colombo_before, Deniyaya_before, Nuwara_Eliya_before, Bibile_before, Kurunegala_before, Jaffna_before]))])
ax.set_xticklabels(['Kandy', 'Colombo', 'Deniyaya', 'Nuwara Eliya', 'Bibile', 'Kurunegala', 'Jaffna'])
ax.legend()

plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:11: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:12: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   if sys.path[0] == "":
# ...
